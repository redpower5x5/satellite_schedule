# %%
import yfinance as yf
import matplotlib.pyplot as plt

# %%
data = yf.download(['SBER.ME', 'GAZP.ME', 'LKOH.ME', 'ROSN.ME', 'GMKN.ME', 'TATN.ME', 'MGNT.ME', 'NVTK.ME', 'ALRS.ME', 'SNGS.ME', 'VTBR.ME', 'AFLT.ME'], start='2021-01-01', end='2023-04-20', interval='1d', group_by='ticker')
data
# Out:
# [*********************100%***********************]  12 of 12 completed
#                 NVTK.ME
#                    Open         High          Low        Close    Adj Close
# Date
# 2021-01-04  1258.800049  1273.599976  1210.400024  1254.800049  1166.559570  \
# 2021-01-05  1258.800049  1275.800049  1240.599976  1274.000000  1184.409302
# 2021-01-06  1253.000000  1306.400024  1273.000000  1302.000000  1210.440308
# 2021-01-08  1302.000000  1302.000000  1302.000000  1302.000000  1210.440308
# 2021-01-11  1375.199951  1434.400024  1361.000000  1403.800049  1305.081665
# ...                 ...          ...          ...          ...          ...
# 2022-05-18  1011.200012  1029.000000  1000.000000  1002.000000  1002.000000
# 2022-05-19  1000.000000  1015.000000   986.000000  1010.799988  1010.799988
# 2022-05-20  1010.799988  1010.799988  1010.799988  1010.799988  1010.799988
# 2022-05-23  1010.799988  1010.799988  1010.799988  1010.799988  1010.799988
# ...

# %%
# Plot all the close prices
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))

# Show the legend
plt.legend()

# Define the label for the title of the figure
plt.title("Adjusted Close Price", fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
# Out:
# /usr/local/lib/python3.11/site-packages/numpy/core/fromnumeric.py:57: RuntimeWarning: invalid value encountered in accumulate
#   return bound(*args, **kwds)

# %%
data.to_csv('out/test_data_for_danya.csv')
